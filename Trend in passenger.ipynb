# %% [markdown]
# ### Importing library and reading file from csv while calculating the descriptive, counting the null value, listing the info of the data and replacing null value with zero

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mtc= pd.read_csv('C:\\Users\\MA1606\\OneDrive - Canterbury Christ Church University\\Documents\\python\\monthly_passengers.csv')

# %%
mtc
# Out:
#      ISO3  Year  Month  Total  Domestic  International  Total_OS
# 0     ALB  2010      1    NaN       NaN            NaN   117.350
# 1     ALB  2010      2    NaN       NaN            NaN    86.535
# 2     ALB  2010      3    NaN       NaN            NaN   103.795
# 3     ALB  2010      4    NaN       NaN            NaN   102.038
# 4     ALB  2010      5    NaN       NaN            NaN   109.037
# ...   ...   ...    ...    ...       ...            ...       ...
# 7237  ZAF  2017      8    NaN       NaN            NaN  3425.617
# 7238  ZAF  2017      9    NaN       NaN            NaN  3454.075
# 7239  ZAF  2017     10    NaN       NaN            NaN  3678.780
# 7240  ZAF  2017     11    NaN       NaN            NaN  3482.341
# 7241  ZAF  2017     12    NaN       NaN            NaN  3812.322
#
# [7242 rows x 7 columns]

# %%
mtc.isnull(). sum()
# Out:
# ISO3                0
# Year                0
# Month               0
# Total            3287
# Domestic         3950
# International    3395
# Total_OS          648
# dtype: int64

# %%
mtc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7242 entries, 0 to 7241
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ISO3           7242 non-null   object
#  1   Year           7242 non-null   int64
#  2   Month          7242 non-null   int64
#  3   Total          3955 non-null   float64
#  4   Domestic       3292 non-null   float64
#  5   International  3847 non-null   float64
#  6   Total_OS       6594 non-null   float64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 396.2+ KB

# %%
mtc.fillna(0)
# Out:
#      ISO3  Year  Month  Total  Domestic  International  Total_OS
# 0     ALB  2010      1    0.0       0.0            0.0   117.350
# 1     ALB  2010      2    0.0       0.0            0.0    86.535
# 2     ALB  2010      3    0.0       0.0            0.0   103.795
# 3     ALB  2010      4    0.0       0.0            0.0   102.038
# 4     ALB  2010      5    0.0       0.0            0.0   109.037
# ...   ...   ...    ...    ...       ...            ...       ...
# 7237  ZAF  2017      8    0.0       0.0            0.0  3425.617
# 7238  ZAF  2017      9    0.0       0.0            0.0  3454.075
# 7239  ZAF  2017     10    0.0       0.0            0.0  3678.780
# 7240  ZAF  2017     11    0.0       0.0            0.0  3482.341
# 7241  ZAF  2017     12    0.0       0.0            0.0  3812.322
#
# [7242 rows x 7 columns]

# %%
mtc.describe ()
# Out:
#               Year        Month         Total      Domestic  International  \
# count  7242.000000  7242.000000   3955.000000   3292.000000     3847.00000
# mean   2014.010909     6.457332   6502.151691   3752.371143     3316.47599
# std       2.427520     3.448825  12487.130185  11588.763321     4317.31194
# min    2010.000000     1.000000     49.478000      0.001000       49.47800
# 25%    2012.000000     3.000000    561.674500      6.660500      472.05700
# 50%    2014.000000     6.000000   2133.740000    167.428500     1710.78300
# 75%    2016.000000     9.000000   6445.708000   1963.495750     3879.65450
# max    2019.000000    12.000000  84373.000000  72697.000000    26498.42400
#
#             Total_OS
# count    6594.000000
# mean     5269.061408
# std     14859.672268
# min        12.756000
# 25%       214.734500
# 50%      1211.110000
# 75%      4664.711000
# max    150581.215000

# %% [markdown]
# ##### The value result show that there is null value in total, domestic and international passenger arrival for certain country within range of 2010 to 2023. Also, the result show that mean value of total passenger is 12,487,130,185 (Which is in millions for all counbtries), the minum value is 49,478,000 and while the max is 84,373,000,000. Furthermore the table also show for domestic and international passenger arrival. the difference and variable will further be represented using chart.

# %% [markdown]
# ##### Now we want to calculate Monthly Trend yearly for total passenger arrival.

# %%
plt.figure(figsize=(14,6))
sns.lineplot(data=mtc, x='Month', y= 'Total', hue='Year', marker='o')
plt.title("Total Monthly passenger Trend")
plt.xlabel("Month")
plt.ylabel("Total passenger")
plt.legend(rotation=45, title='Year')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'x'
#
# ...
